# %% [markdown]
# <a href="https://colab.research.google.com/github/JalpaK88/Projects_SQL/blob/main/SQL_bigquery_stackoverflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
from google.cloud import bigquery

# Step 1: Authenticate
auth.authenticate_user()

# Step 2: Prompt user for project ID
PROJECT_ID = input("Enter your GCP project ID: ").strip()

# Check if a project ID was entered
if not PROJECT_ID:
    raise ValueError("You must enter a valid GCP project ID!")

# Step 3: Initialize BigQuery client with the provided project ID
client = bigquery.Client(project=PROJECT_ID)
print("Using project:", client.project)

dataset_ref = client.dataset("stackoverflow", project="bigquery-public-data")
dataset = client.get_dataset(dataset_ref)
# table_ref = dataset_ref.table("transactions")
# table = client.get_table(table_ref)
# rows= client.list_rows(table,max_results=5).to_dataframe()
# rows
# Out:
# Enter your GCP project ID: brilliant-flame-471022-p3
# Using project: brilliant-flame-471022-p3

# %%
# List all tables in the dataset
tables = list(client.list_tables(dataset_ref))

print("Tables in dataset:")
for table in tables:
    print(table.table_id)
# Out:
# Tables in dataset:
# badges
# comments
# post_history
# post_links
# posts_answers
# posts_moderator_nomination
# posts_orphaned_tag_wiki
# posts_privilege_wiki
# posts_questions
# posts_tag_wiki
# posts_tag_wiki_excerpt
# posts_wiki_placeholder
# stackoverflow_posts
# tags
# users
# votes

# %%
# Construct a reference to the "posts_answers" table
answers_table_ref = dataset_ref.table("posts_answers")

# API request - fetch the table
answers_table = client.get_table(answers_table_ref)

# Preview the first five lines of the "posts_answers" table
rows = client.list_rows(answers_table, max_results=5).to_dataframe()
rows
# Out:
#      id title                                               body  \
# 0    18  None  <p>For a table like this:</p>\n\n<pre><code>CR...
# 1   165  None  <p>You can use a <a href="http://sharpdevelop....
# 2  1028  None  <p>The VB code looks something like this:</p>\...
# 3  1073  None  <p>My first choice would be a dedicated heap t...
# 4  1260  None  <p>I found the answer. all you have to do is a...
#
#   accepted_answer_id answer_count  comment_count community_owned_date  \
# 0               None         None              2                  NaT
# 1               None         None              0                  NaT
# 2               None         None              0                  NaT
# 3               None         None              0                  NaT
# 4               None         None              0                  NaT
#
#                      creation_date favorite_count  \
# 0 2008-08-01 05:12:44.193000+00:00           None
# ...

# %%
# Construct a reference to the "posts_questions" table
questions_table_ref = dataset_ref.table("posts_questions")

# API request - fetch the table
questions_table = client.get_table(questions_table_ref)

# Preview the first five lines of the "posts_questions" table
rows_2 = client.list_rows(questions_table, max_results=5).to_dataframe()
rows_2
# Out:
#        id                                              title  \
# 0  320268          Html.ActionLink doesn’t render # properly
# 1  324003                                Primitive recursion
# 2  390605                                 While vs. Do While
# 3  413246                        Protect ASP.NET Source code
# 4  454921  Difference between "int[] myArray" and "int my...
#
#                                                 body  accepted_answer_id  \
# 0  <p>When using Html.ActionLink passing a string...                <NA>
# 1  <p>how  will i define the function 'simplify' ...                <NA>
# 2  <p>I've seen both the blocks of code in use se...              390608
# 3  <p>Im currently doing some research in how to ...                <NA>
# 4  <blockquote>\n  <p><strong>Possible Duplicate:...              454928
#
#    answer_count  comment_count community_owned_date  \
# 0             0              0                  NaT
# ...

# %%
# use of LIKE to find bigquery string in tags
questions_query = """
                  SELECT id, title, owner_user_id
                  FROM `bigquery-public-data.stackoverflow.posts_questions`
                  WHERE tags LIKE '%bigquery%'
                  """

# %%
query_like = client.query(questions_query)

# %%
num_title = query_like.to_dataframe()

# %%
# num_title
num_title.head()
# Out:
#          id                                              title  owner_user_id
# 0  73842189  Need to map JSON file fields and store it in a...       19234248
# 1  73565487      Big Query data ingestion cost for storage api       17359564
# 2  73648727  What do I do if I can't select options from th...       19949405
# 3  73722616  Best solution to port Snapfulfil WMS to Google...       19998126
# 4  73709704        BigQuery "... was not found in location US"       19778247

# %%
# join query
# Write a query that returns the id, body and owner_user_id columns from the posts_answers table for answers to "bigquery"-related questions.
answers_query = """
                SELECT a.id, a.body, a.owner_user_id
                FROM `bigquery-public-data.stackoverflow.posts_questions` AS q
                INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS a
                    ON q.id = a.parent_id
                WHERE q.tags LIKE '%bigquery%'
                """

# %%
answer_query = client.query(answers_query)

# %%
data_query = answer_query.to_dataframe()

# %%
# data_query
data_query.head()
# Out:
#          id                                               body  owner_user_id
# 0  61161673  <p>Depends on the kind of automation needed. F...        8881300
# 1  61168340  <p>As long as you have the <code>GOOGLE_APPLIC...        4334376
# 2  61173041  <p>First, probably it's better to provide your...        4334376
# 3  61185926  <p>Here is a way to do this...</p>\n\n<pre><co...        7137090
# 4  61212468  <p>The "specialGroup" possible values, are ana...        5431502

# %%
# You have the merge you need.
# But you want a list of users who have answered many questions... which requires more work beyond your previous result.
# Write a new query that has a single row for each user who answered at least one question with a tag that includes the string "bigquery". Your results should have two columns:

# user_id - contains the owner_user_id column from the posts_answers table
# number_of_answers - contains the number of answers the user has written to "bigquery"-related questions

bigquery_experts_query = """
                         SELECT a.owner_user_id AS user_id, COUNT(1) AS number_of_answers
                         FROM `bigquery-public-data.stackoverflow.posts_questions` AS q
                         INNER JOIN `bigquery-public-data.stackoverflow.posts_answers` AS a
                             ON q.id = a.parent_Id
                         WHERE q.tags LIKE '%bigquery%'
                         GROUP BY a.owner_user_id
                         """

# %%
answer_query = client.query(bigquery_experts_query)

# %%
data_query = answer_query.to_dataframe()

# %%
data_query.head()
# Out:
#     user_id  number_of_answers
# 0   3257867                 15
# 1   2291321                  1
# 2    248432                  3
# 3  14751010                  1
# 4   3175889                  7
